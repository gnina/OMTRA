# %%
import pickle
import pandas as pd

# %% [markdown]
# # Ligand Conformer

# %%
metrics = {}

pd.options.display.float_format = "{:.3f}".format


with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/uncond_stoch_sampling/lig_conformer/ligand_conformer_condensed_metrics.pkl", "rb") as f:
     lig_conf_stoch_sampling = pickle.load(f)
     metrics['stoch_sampling'] = lig_conf_stoch_sampling

with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/uncond/lig_conformer/ligand_conformer_condensed_metrics.pkl", "rb") as f:
     lig_conf = pickle.load(f)
     metrics['regular'] = lig_conf

metrics = pd.DataFrame(metrics)
metrics
# Out:
#                                    stoch_sampling  regular
# frac_atoms_stable                           1.000    1.000
# frac_mols_stable_valence                    1.000    1.000
# flag_rate                                   0.160    0.160
# ood_rate                                    0.000    0.000
# flatness_max_distance_from_plane            0.015    0.014
# flatness_frac_ring_systems_passed           1.000    1.000
# ligand_rmsd                                 5.274    5.455
# ligand_kabsch_rmsd                          1.703    1.764
# ligand_centroid_distance                    0.191    0.127
# pb_valid                                    1.000    1.000
# pb_mol_pred_loaded                          1.000    1.000
# pb_sanitization                             1.000    1.000
# pb_inchi_convertible                        1.000    1.000
# pb_all_atoms_connected                      1.000    1.000
# pb_bond_lengths                             1.000    1.000
# pb_bond_angles                              1.000    1.000
# pb_internal_steric_clash                    1.000    1.000
# pb_aromatic_ring_flatness                   1.000    1.000
# pb_non-aromatic_ring_non-flatness           1.000    1.000
# pb_double_bond_flatness                     1.000    1.000

# %% [markdown]
# ## De Novo Ligand

# %%
metrics = {}

with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/uncond_stoch_sampling/denovo_lig/denovo_ligand_condensed_metrics.pkl", "rb") as f:
    denovo_lig_stoch_sampling = pickle.load(f)
    metrics['stoch_sampling'] = denovo_lig_stoch_sampling

with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/uncond/denovo_lig/denovo_ligand_condensed_metrics.pkl", "rb") as f:
     denovo_lig = pickle.load(f)
     metrics['regular'] = denovo_lig

metrics = pd.DataFrame(metrics)
metrics
# Out:
#                                    stoch_sampling  regular
# frac_atoms_stable                           1.000    1.000
# frac_mols_stable_valence                    0.997    0.997
# flag_rate                                   0.528    0.629
# ood_rate                                    0.435    0.030
# flatness_max_distance_from_plane            0.048    0.030
# flatness_frac_ring_systems_passed           0.955    0.996
# frac_valid_mols                             0.997    0.997
# avg_frag_frac                               1.000    0.999
# avg_num_components                          1.000    1.003
# frac_connected                              1.000    0.997
# pb_valid                                    0.953    0.990
# pb_mol_pred_loaded                          1.000    1.000
# pb_sanitization                             1.000    1.000
# pb_inchi_convertible                        1.000    1.000
# pb_all_atoms_connected                      1.000    0.997
# pb_bond_lengths                             1.000    0.997
# pb_bond_angles                              1.000    1.000
# pb_internal_steric_clash                    0.973    1.000
# pb_aromatic_ring_flatness                   0.997    1.000
# pb_non-aromatic_ring_non-flatness           0.997    1.000
# pb_double_bond_flatness                     0.983    1.000

# %% [markdown]
# ## Ligand Conformer from Pharmacophore

# %%
metrics = {}

pd.options.display.float_format = "{:.3f}".format

with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/phcond_seeded_stoch_sampling/lig_conformer_from_pharm/ligand_conformer_from_pharmacophore_condensed_metrics.pkl", "rb") as f:
     lig_conf_stoch_sampling = pickle.load(f)
     metrics['stoch_sampling'] = lig_conf_stoch_sampling

with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/phcond_seeded/lig_conformer_from_pharm/ligand_conformer_from_pharmacophore_condensed_metrics.pkl", "rb") as f:
      lig_conf = pickle.load(f)
      metrics['regular'] = lig_conf

metrics = pd.DataFrame(metrics)
metrics
# Out:
#                                    stoch_sampling  regular
# frac_atoms_stable                           1.000    1.000
# frac_mols_stable_valence                    1.000    1.000
# flag_rate                                   0.160    0.160
# ood_rate                                    0.000    0.000
# flatness_max_distance_from_plane            0.021    0.029
# flatness_frac_ring_systems_passed           1.000    0.991
# ligand_rmsd                                 1.665    1.835
# ligand_kabsch_rmsd                          1.076    1.120
# ligand_centroid_distance                    0.192    0.153
# pb_valid                                    0.973    0.957
# pb_mol_pred_loaded                          1.000    1.000
# pb_sanitization                             1.000    1.000
# pb_inchi_convertible                        1.000    1.000
# pb_all_atoms_connected                      1.000    1.000
# pb_bond_lengths                             0.973    0.960
# pb_bond_angles                              1.000    0.987
# pb_internal_steric_clash                    1.000    1.000
# pb_aromatic_ring_flatness                   1.000    1.000
# pb_non-aromatic_ring_non-flatness           1.000    1.000
# pb_double_bond_flatness                     1.000    1.000
# frac_pharm_samples_matching                 0.990    0.983
# frac_true_centers_matched                   0.997    0.994

# %% [markdown]
# ## De Novo Ligand from Pharmacophore

# %%
metrics = {}

with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/phcond_seeded_stoch_sampling/denovo_lig_from_pharm/denovo_ligand_from_pharmacophore_condensed_metrics.pkl", "rb") as f:
    denovo_lig_stoch_sampling = pickle.load(f)
    metrics['stoch_sampling'] = denovo_lig_stoch_sampling

with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/phcond_seeded/denovo_lig_from_pharm/denovo_ligand_from_pharmacophore_condensed_metrics.pkl", "rb") as f:
     denovo_lig = pickle.load(f)
     metrics['regular'] = denovo_lig

metrics = pd.DataFrame(metrics)
metrics
# Out:
#                                    stoch_sampling  regular
# frac_atoms_stable                           0.998    1.000
# frac_mols_stable_valence                    0.966    0.992
# flag_rate                                   0.791    0.575
# ood_rate                                    0.413    0.066
# flatness_max_distance_from_plane            0.085    0.054
# flatness_frac_ring_systems_passed           0.862    0.964
# frac_valid_mols                             0.968    0.994
# avg_frag_frac                               0.994    0.994
# avg_num_components                          1.022    1.022
# frac_connected                              0.978    0.982
# pb_valid                                    0.694    0.894
# pb_mol_pred_loaded                          1.000    1.000
# pb_sanitization                             1.000    1.000
# pb_inchi_convertible                        1.000    1.000
# pb_all_atoms_connected                      0.977    0.982
# pb_bond_lengths                             0.787    0.930
# pb_bond_angles                              0.921    0.976
# pb_internal_steric_clash                    0.990    0.994
# pb_aromatic_ring_flatness                   0.986    0.996
# pb_non-aromatic_ring_non-flatness           0.998    1.000
# pb_double_bond_flatness                     0.977    0.996
# frac_pharm_samples_matching                 0.784    0.906
# frac_true_centers_matched                   0.923    0.969

# %%
## 500 samples
pd.options.display.float_format = "{:.3f}".format

metrics = {}

with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/phcond_seeded_stoch_sampling/denovo_lig_from_pharm/denovo_ligand_from_pharmacophore_condensed_metrics.pkl", "rb") as f:
    denovo_lig_stoch_sampling = pickle.load(f)
    metrics['stoch_sampling'] = denovo_lig_stoch_sampling

with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/phcond_seeded/denovo_lig_from_pharm/denovo_ligand_from_pharmacophore_condensed_metrics.pkl", "rb") as f:
     denovo_lig = pickle.load(f)
     metrics['regular'] = denovo_lig

metrics = pd.DataFrame(metrics)
metrics
# Out:
#                                    stoch_sampling  regular
# frac_atoms_stable                           0.998    1.000
# frac_mols_stable_valence                    0.966    0.992
# flag_rate                                   0.791    0.575
# ood_rate                                    0.413    0.066
# flatness_max_distance_from_plane            0.085    0.054
# flatness_frac_ring_systems_passed           0.862    0.964
# frac_valid_mols                             0.968    0.994
# avg_frag_frac                               0.994    0.994
# avg_num_components                          1.022    1.022
# frac_connected                              0.978    0.982
# pb_valid                                    0.694    0.894
# pb_mol_pred_loaded                          1.000    1.000
# pb_sanitization                             1.000    1.000
# pb_inchi_convertible                        1.000    1.000
# pb_all_atoms_connected                      0.977    0.982
# pb_bond_lengths                             0.787    0.930
# pb_bond_angles                              0.921    0.976
# pb_internal_steric_clash                    0.990    0.994
# pb_aromatic_ring_flatness                   0.986    0.996
# pb_non-aromatic_ring_non-flatness           0.998    1.000
# pb_double_bond_flatness                     0.977    0.996
# frac_pharm_samples_matching                 0.784    0.906
# frac_true_centers_matched                   0.923    0.969
