# %%
import pickle
import pandas as pd

# %% [markdown]
# # Ligand Conformer

# %%
metrics = {}

pd.options.display.float_format = "{:.3f}".format


with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/uncond_stoch_sampling/lig_conformer/ligand_conformer_condensed_metrics.pkl", "rb") as f:
    lig_conf_stoch_sampling = pickle.load(f)
    metrics['stoch_sampling'] = lig_conf_stoch_sampling

with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/uncond/lig_conformer/ligand_conformer_condensed_metrics.pkl", "rb") as f:
     lig_conf = pickle.load(f)
     metrics['regular'] = lig_conf

with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/uncond_stoch_sampling/lig_conformer_ts700/ligand_conformer_condensed_metrics.pkl", "rb") as f:
    lig_conf_stoch_sampling = pickle.load(f)
    metrics['stoch_sampling(ts=700)'] = lig_conf_stoch_sampling

metrics = pd.DataFrame(metrics)
metrics
# Out:
#                                    stoch_sampling  regular
# ligand_rmsd                                 5.158    4.947  \
# ligand_kabsch_rmsd                          1.940    1.917
# ligand_centroid_distance                    0.197    0.192
# frac_atoms_stable                           1.000    1.000
# frac_mols_stable_valence                    1.000    1.000
# flag_rate                                   0.160    0.160
# ood_rate                                    0.000    0.000
# geometry_frac_valid_bonds                   1.000    1.000
# geometry_frac_valid_angles                  1.000    1.000
# geometry_number_clashes                     0.003    0.003
# flatness_max_distance_from_plane            0.010    0.010
# flatness_frac_ring_systems_passed           1.000    1.000
# pb_valid                                    0.997    1.000
# pb_mol_pred_loaded                          1.000    1.000
# pb_sanitization                             1.000    1.000
# ...

# %% [markdown]
# ## De Novo Ligand

# %%
metrics = {}

with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/uncond_stoch_sampling/denovo_lig/denovo_ligand_condensed_metrics.pkl", "rb") as f:
    denovo_lig_stoch_sampling = pickle.load(f)
    metrics['stoch_sampling'] = denovo_lig_stoch_sampling

with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/uncond/denovo_lig/denovo_ligand_condensed_metrics.pkl", "rb") as f:
     denovo_lig = pickle.load(f)
     metrics['regular'] = denovo_lig

with open("/net/galaxy/home/koes/ltoft/OMTRA/samples/uncond_stoch_sampling/denovo_lig_ts700/denovo_ligand_condensed_metrics.pkl", "rb") as f:
    denovo_lig_stoch_sampling = pickle.load(f)
    metrics['stoch_sampling(ts=700)'] = denovo_lig_stoch_sampling

metrics = pd.DataFrame(metrics)
metrics
# Out:
#                                    stoch_sampling  regular
# frac_valid_mols                             0.990    0.993  \
# avg_frag_frac                               0.998    1.000
# avg_num_components                          1.003    1.003
# frac_connected                              0.997    0.997
# frac_atoms_stable                           0.999    1.000
# frac_mols_stable_valence                    0.990    0.990
# flag_rate                                   0.508    0.362
# ood_rate                                    0.468    0.426
# geometry_frac_valid_bonds                   1.000    1.000
# geometry_frac_valid_angles                  1.000    1.000
# geometry_number_clashes                     0.064    0.084
# flatness_max_distance_from_plane            0.046    0.042
# flatness_frac_ring_systems_passed           0.973    0.972
# pb_valid                                    0.947    0.970
# pb_mol_pred_loaded                          1.000    1.000
# ...
